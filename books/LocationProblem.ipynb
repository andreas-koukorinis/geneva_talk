# %%
import talk.config as con

# environment variable for MOSEK
con.config_configManager()
con.config_matplotlib()

# %% [markdown]
# ### Location problem
#
# We want to find the smallest circle such that $n$ points are all contained in it.

# %%
# pick a bunch of random points
import numpy as np
pos = np.random.randn(1000,2)

import matplotlib.pyplot as plt
plt.scatter(pos[:,0], pos[:,1],s=50,marker=u'x')
plt.xlabel('x'), plt.ylabel('y')
plt.axis('equal')
plt.show()

# %%
from mosek.fusion import *

def two_norm(model, v):
    t = model.variable(1, Domain.greaterThan(0.0))
    model.constraint(Expr.vstack(t, v), Domain.inQCone())
    return t

def __abs(model, v):
    t = model.variable(int(v.size()), Domain.greaterThan(0.0))
    model.constraint(Expr.hstack(t, v), Domain.inQCone(int(v.size()), 2))
    return t

def infty_norm(model, v):
    t = __abs(model, v)
    m = model.variable(1, Domain.unbounded())
    model.constraint(Expr.sub(Var.repeat(m,int(t.size())),t), Domain.greaterThan(0.0))
    return m

# %%
from mosek.fusion import *
    
with Model('center') as model:
    # variable for the center
    p = model.variable('p', 2, Domain.unbounded())
    # Distances for each point from the centre
    distances = Expr.vstack([two_norm(model, Expr.sub(Expr.constTerm(row),p)).asExpr() for row in pos])
    # max distance!
    m = infty_norm(model, distances)
    
    model.objective(ObjectiveSense.Minimize, m)
    model.solve()
    
    midpoint = np.array(p.level())
    radius = m.level()[0]
    
import math
c=np.array([[radius*np.cos(a)+midpoint[0], radius*np.sin(a)+midpoint[1]] for a in np.linspace(0,2*math.pi,1000)])

import matplotlib.pyplot as plt
plt.plot(c[:,0],c[:,1],'r')
plt.scatter(pos[:,0], pos[:,1],s=50,marker=u'x')
plt.xlabel('x'), plt.ylabel('y')
plt.axis('equal')
plt.show()
print(midpoint)
print(radius)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /opt/conda/lib/python3.5/site-packages/mosek/fusion/impl/_implementation.py in _task_1solve_(self)
#    2740           self.__break = False
# -> 2741           trmcode = task.optimize()
#    2742         except mosek.Error as e:
#
# /opt/conda/lib/python3.5/site-packages/mosek/__init__.py in accept(*args)
#     126             try:
# --> 127                 return fun(*[ t(a) for (t,a) in zip(argtlst,args) ])
#     128             except TypeAcceptError as e:
#
# /opt/conda/lib/python3.5/site-packages/mosek/__init__.py in optimize(self)
#    7423       result,msg = self.__getlasterror(res)
# -> 7424       raise Error(rescode(res),Env.getcodedesc(rescode(res))[1])
#    7425     _trmcode_return_value = rescode(trmcode_.value)
#
# Error: (1001) The license has expired.
#
# During handling of the above exception, another exception occurred:
#
# OptimizeError                             Traceback (most recent call last)
# <ipython-input-4-4a580d9b3f18> in <module>()
#      10
#      11     model.objective(ObjectiveSense.Minimize, m)
# ---> 12     model.solve()
#      13
#      14     midpoint = np.array(p.level())
#
# /opt/conda/lib/python3.5/site-packages/mosek/fusion/impl/_implementation.py in solve(self, *args)
#    3170     if False: pass
#    3171     elif mosek_fusion_Model._match_solve_(*args): #
# -> 3172       return self._solve_(*args)
#    3173     elif mosek_fusion_Model._match_alt_solve_(*args): #
#    3174       return self._solve_alt_(*args)
#
# /opt/conda/lib/python3.5/site-packages/mosek/fusion/impl/_implementation.py in _solve_(self)
#    3985    self.__flush_1initsol_Emosek_4fusion_4SolutionType_2(mosek.fusion.SolutionType.Integer)
#    3986    self.__flush_1initsol_Emosek_4fusion_4SolutionType_2(mosek.fusion.SolutionType.Basic)
# -> 3987    self._task_1solve_()
#    3988   @staticmethod
#    3989   def _match_flushSolutions_(*args):
#
# /opt/conda/lib/python3.5/site-packages/mosek/fusion/impl/_implementation.py in _task_1solve_(self)
#    2741           trmcode = task.optimize()
#    2742         except mosek.Error as e:
# -> 2743           raise mosek_fusion_OptimizeError(e.msg)
#    2744         except mosek.Warning as e:
#    2745           pass
#
# OptimizeError: The license has expired.
